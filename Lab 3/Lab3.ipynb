# %% [markdown]
# Sentiment Analysis on Scrapped News

# %%
import requests
from bs4 import BeautifulSoup
from transformers import pipeline
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

def fetch_news_headlines(url):
    """
    Scrape news headlines from the provided URL.
    This example uses Inshorts, where headlines are contained in <span> tags with itemprop="headline".
    Adjust the selector as needed for your target site.
    """
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print("Error fetching news, status code:", response.status_code)
        return []

    soup = BeautifulSoup(response.content, 'html.parser')
    # For Inshorts, headlines are in <span> tags with attribute itemprop="headline"
    headline_elements = soup.find_all("span", {"itemprop": "headline"})
    headlines = [element.get_text(strip=True) for element in headline_elements]
    return headlines

def analyze_sentiments(headlines):
    """
    Analyze the sentiment of each headline using Hugging Face's transformer pipeline.
    The model used here is "distilbert-base-uncased-finetuned-sst-2-english".
    """
    sentiment_pipeline = pipeline("sentiment-analysis",
                                  model="distilbert-base-uncased-finetuned-sst-2-english")
    sentiments = sentiment_pipeline(headlines)
    return sentiments

def generate_word_cloud(text_list):
    """
    Generate and display a word cloud from the list of news headlines.
    """
    text = " ".join(text_list)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title("Word Cloud of News Headlines")
    plt.show()

def plot_sentiment_distribution(sentiments):
    """
    Create a bar chart that shows the frequency of each sentiment label.
    """
    # Extract sentiment labels from the results
    labels = [result['label'] for result in sentiments]
    sentiment_counts = Counter(labels)

    # Prepare data for plotting
    labels_list, counts = zip(*sentiment_counts.items())

    # Color bars based on sentiment (green for positive, red for negative)
    colors = ['green' if label.upper() == 'POSITIVE' else 'red' for label in labels_list]

    plt.figure(figsize=(8, 5))
    plt.bar(labels_list, counts, color=colors)
    plt.xlabel("Sentiment")
    plt.ylabel("Number of Headlines")
    plt.title("Sentiment Distribution of News Headlines")
    plt.show()

def main():
    # URL for Inshorts news headlines (ensure scraping is permitted for educational use)
    url = "https://inshorts.com/en/read"
    headlines = fetch_news_headlines(url)

    if not headlines:
        print("No headlines found. Please check the URL or HTML selectors.")
        return

    sentiments = analyze_sentiments(headlines)

    # Print each headline with its corresponding sentiment result
    for headline, sentiment in zip(headlines, sentiments):
        print("Headline:", headline)
        print("Sentiment:", sentiment)
        print("-" * 80)

    # Visualization 1: Word Cloud of headlines
    generate_word_cloud(headlines)

    # Visualization 2: Bar chart of sentiment distribution
    plot_sentiment_distribution(sentiments)

if __name__ == "__main__":
    main()
# Out:
# Device set to use cpu
# Headline: Passenger plane crashes and flips at airport in Canada
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9976385831832886}
# --------------------------------------------------------------------------------
# Headline: Gyanesh Kumar appointed new Chief Election Commissioner
# Sentiment: {'label': 'POSITIVE', 'score': 0.9980636239051819}
# --------------------------------------------------------------------------------
# Headline: Indian Embassy in Nepal reacts to Nepali student's death by suicide at Odisha university
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9920496344566345}
# --------------------------------------------------------------------------------
# Headline: Congress distances itself from Sam Pitroda's 'Don't assume China as enemy' remark
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9953147172927856}
# --------------------------------------------------------------------------------
# Headline: Cameron Green gets engaged to longtime girlfriend Emily Redwood
# Sentiment: {'label': 'POSITIVE', 'score': 0.9859547019004822}
# --------------------------------------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
from transformers import pipeline
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
import time  # To add delays between requests

def fetch_news_headlines():
    """
    Fetch multiple pages of Inshorts news headlines.
    """
    base_url = "https://inshorts.com/en/read"
    headlines = []
    categories = ["all", "technology", "sports", "entertainment", "business"]  # Change categories if needed

    for category in categories:
        page = 1
        while page <= 3:  # Fetch 3 pages per category
            print(f"Fetching {category} - Page {page}...")
            url = f"https://inshorts.com/en/read/{category}"
            headers = {'User-Agent': 'Mozilla/5.0'}
            response = requests.get(url, headers=headers)

            if response.status_code != 200:
                print("Error fetching news, status code:", response.status_code)
                break  # Stop if there's an issue

            soup = BeautifulSoup(response.content, 'html.parser')
            headline_elements = soup.find_all("span", {"itemprop": "headline"})
            new_headlines = [element.get_text(strip=True) for element in headline_elements]

            if not new_headlines:
                break  # Stop if no new headlines found (pagination limit reached)

            headlines.extend(new_headlines)
            page += 1
            time.sleep(2)  # Avoid rate-limiting

    return headlines

def analyze_sentiments(headlines):
    """
    Analyze the sentiment of each headline using Hugging Face's transformer pipeline.
    """
    sentiment_pipeline = pipeline("sentiment-analysis",
                                  model="distilbert-base-uncased-finetuned-sst-2-english")
    sentiments = sentiment_pipeline(headlines)
    return sentiments

def generate_word_cloud(text_list):
    """
    Generate and display a word cloud from the list of news headlines.
    """
    text = " ".join(text_list)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title("Word Cloud of News Headlines")
    plt.show()

def plot_sentiment_distribution(sentiments):
    """
    Create a bar chart that shows the frequency of each sentiment label.
    """
    labels = [result['label'] for result in sentiments]
    sentiment_counts = Counter(labels)

    labels_list, counts = zip(*sentiment_counts.items())
    colors = ['green' if label.upper() == 'POSITIVE' else 'red' for label in labels_list]

    plt.figure(figsize=(8, 5))
    plt.bar(labels_list, counts, color=colors)
    plt.xlabel("Sentiment")
    plt.ylabel("Number of Headlines")
    plt.title("Sentiment Distribution of News Headlines")
    plt.show()

def main():
    headlines = fetch_news_headlines()

    if not headlines:
        print("No headlines found. Please check the URL or HTML selectors.")
        return

    sentiments = analyze_sentiments(headlines)

    # Print each headline with its corresponding sentiment result
    for headline, sentiment in zip(headlines, sentiments):
        print("Headline:", headline)
        print("Sentiment:", sentiment)
        print("-" * 80)

    # Visualization
    generate_word_cloud(headlines)
    plot_sentiment_distribution(sentiments)

if __name__ == "__main__":
    main()
# Out:
# Fetching all - Page 1...
# Fetching all - Page 2...
# Fetching all - Page 3...
# Fetching technology - Page 1...
# Fetching technology - Page 2...
# Fetching technology - Page 3...
# Fetching sports - Page 1...
# Fetching sports - Page 2...
# Fetching sports - Page 3...
# Fetching entertainment - Page 1...
# Fetching entertainment - Page 2...
# Fetching entertainment - Page 3...
# Fetching business - Page 1...
# Fetching business - Page 2...
# Fetching business - Page 3...
# Device set to use cpu
# Headline: The Beautiful Craft of Chandi Tarakasi
# Sentiment: {'label': 'POSITIVE', 'score': 0.9998045563697815}
# --------------------------------------------------------------------------------
# Headline: When "The Beatles" visited India in 1968
# Sentiment: {'label': 'POSITIVE', 'score': 0.9922457337379456}
# --------------------------------------------------------------------------------
# Headline: Sajan Prakash and Karnataka teams break National Games records
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995662569999695}
# --------------------------------------------------------------------------------
# Headline: All about the Carpet Weaving technique of Sikkim
# Sentiment: {'label': 'POSITIVE', 'score': 0.9944156408309937}
# --------------------------------------------------------------------------------
# Headline: Kishore Kumar Jena opens up on challenging period
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995786547660828}
# --------------------------------------------------------------------------------
# Headline: Roopkund: The Lake of Skeletons in Himalayas
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9577173590660095}
# --------------------------------------------------------------------------------
# Headline: Charminar: The Pride of Hyderabad
# Sentiment: {'label': 'POSITIVE', 'score': 0.9997947812080383}
# --------------------------------------------------------------------------------
# Headline: Sumit Antil looked up to Neeraj Chopra for inspiration
# Sentiment: {'label': 'POSITIVE', 'score': 0.9965617060661316}
# --------------------------------------------------------------------------------
# Headline: Mamaearth IPO subscribed 7.61 times on final day
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9865769147872925}
# --------------------------------------------------------------------------------
# Headline: Mohammed Shami's 5-wicket haul guides India to CWC'23 semifinals
# Sentiment: {'label': 'POSITIVE', 'score': 0.9990925788879395}
# --------------------------------------------------------------------------------
# Headline: The Beautiful Craft of Chandi Tarakasi
# Sentiment: {'label': 'POSITIVE', 'score': 0.9998045563697815}
# --------------------------------------------------------------------------------
# Headline: When "The Beatles" visited India in 1968
# Sentiment: {'label': 'POSITIVE', 'score': 0.9922457337379456}
# --------------------------------------------------------------------------------
# Headline: Sajan Prakash and Karnataka teams break National Games records
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995662569999695}
# --------------------------------------------------------------------------------
# Headline: All about the Carpet Weaving technique of Sikkim
# Sentiment: {'label': 'POSITIVE', 'score': 0.9944156408309937}
# --------------------------------------------------------------------------------
# Headline: Kishore Kumar Jena opens up on challenging period
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995786547660828}
# --------------------------------------------------------------------------------
# Headline: Roopkund: The Lake of Skeletons in Himalayas
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9577173590660095}
# --------------------------------------------------------------------------------
# Headline: Charminar: The Pride of Hyderabad
# Sentiment: {'label': 'POSITIVE', 'score': 0.9997947812080383}
# --------------------------------------------------------------------------------
# Headline: Sumit Antil looked up to Neeraj Chopra for inspiration
# Sentiment: {'label': 'POSITIVE', 'score': 0.9965617060661316}
# --------------------------------------------------------------------------------
# Headline: Mamaearth IPO subscribed 7.61 times on final day
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9865769147872925}
# --------------------------------------------------------------------------------
# Headline: Mohammed Shami's 5-wicket haul guides India to CWC'23 semifinals
# Sentiment: {'label': 'POSITIVE', 'score': 0.9990925788879395}
# --------------------------------------------------------------------------------
# Headline: The Beautiful Craft of Chandi Tarakasi
# Sentiment: {'label': 'POSITIVE', 'score': 0.9998045563697815}
# --------------------------------------------------------------------------------
# Headline: When "The Beatles" visited India in 1968
# Sentiment: {'label': 'POSITIVE', 'score': 0.9922457337379456}
# --------------------------------------------------------------------------------
# Headline: Sajan Prakash and Karnataka teams break National Games records
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995662569999695}
# --------------------------------------------------------------------------------
# Headline: All about the Carpet Weaving technique of Sikkim
# Sentiment: {'label': 'POSITIVE', 'score': 0.9944156408309937}
# --------------------------------------------------------------------------------
# Headline: Kishore Kumar Jena opens up on challenging period
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995786547660828}
# --------------------------------------------------------------------------------
# Headline: Roopkund: The Lake of Skeletons in Himalayas
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9577173590660095}
# --------------------------------------------------------------------------------
# Headline: Charminar: The Pride of Hyderabad
# Sentiment: {'label': 'POSITIVE', 'score': 0.9997947812080383}
# --------------------------------------------------------------------------------
# Headline: Sumit Antil looked up to Neeraj Chopra for inspiration
# Sentiment: {'label': 'POSITIVE', 'score': 0.9965617060661316}
# --------------------------------------------------------------------------------
# Headline: Mamaearth IPO subscribed 7.61 times on final day
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9865769147872925}
# --------------------------------------------------------------------------------
# Headline: Mohammed Shami's 5-wicket haul guides India to CWC'23 semifinals
# Sentiment: {'label': 'POSITIVE', 'score': 0.9990925788879395}
# --------------------------------------------------------------------------------
# Headline: Stop trying to pull India down!: Pai to Rahul on drone video
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9968461394309998}
# --------------------------------------------------------------------------------
# Headline: How AI & innovation are redefining beauty and wellness landscape
# Sentiment: {'label': 'POSITIVE', 'score': 0.9996477365493774}
# --------------------------------------------------------------------------------
# Headline: US headed to dystopian future: Bikhchandani on Musk working in US govt
# Sentiment: {'label': 'POSITIVE', 'score': 0.7400269508361816}
# --------------------------------------------------------------------------------
# Headline: DeepSeek AI app suspended for local use in South Korea
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9975570440292358}
# --------------------------------------------------------------------------------
# Headline: TCS to give 4-8% average hike to employees, will link it to return-to-office mandate: Report
# Sentiment: {'label': 'NEGATIVE', 'score': 0.6848200559616089}
# --------------------------------------------------------------------------------
# Headline: Argentina Prez may face impeachment trial over promoting crypto that crashed
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9866672158241272}
# --------------------------------------------------------------------------------
# Headline: Hyderabad startup uses AI to cut construction delays & costs
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9804572463035583}
# --------------------------------------------------------------------------------
# Headline: How is nuclear facilites' tech helping maintain hygiene at Maha Kumbh?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9995427131652832}
# --------------------------------------------------------------------------------
# Headline: Ashley reveals how she met Musk for the 1st time, claims she was 24 & he was 51 at the time
# Sentiment: {'label': 'POSITIVE', 'score': 0.9947880506515503}
# --------------------------------------------------------------------------------
# Headline: Study finds how new technology enhances gravitational-wave detection
# Sentiment: {'label': 'POSITIVE', 'score': 0.9993897676467896}
# --------------------------------------------------------------------------------
# Headline: Stop trying to pull India down!: Pai to Rahul on drone video
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9968461394309998}
# --------------------------------------------------------------------------------
# Headline: How AI & innovation are redefining beauty and wellness landscape
# Sentiment: {'label': 'POSITIVE', 'score': 0.9996477365493774}
# --------------------------------------------------------------------------------
# Headline: US headed to dystopian future: Bikhchandani on Musk working in US govt
# Sentiment: {'label': 'POSITIVE', 'score': 0.7400269508361816}
# --------------------------------------------------------------------------------
# Headline: DeepSeek AI app suspended for local use in South Korea
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9975570440292358}
# --------------------------------------------------------------------------------
# Headline: TCS to give 4-8% average hike to employees, will link it to return-to-office mandate: Report
# Sentiment: {'label': 'NEGATIVE', 'score': 0.6848200559616089}
# --------------------------------------------------------------------------------
# Headline: Argentina Prez may face impeachment trial over promoting crypto that crashed
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9866672158241272}
# --------------------------------------------------------------------------------
# Headline: Hyderabad startup uses AI to cut construction delays & costs
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9804572463035583}
# --------------------------------------------------------------------------------
# Headline: How is nuclear facilites' tech helping maintain hygiene at Maha Kumbh?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9995427131652832}
# --------------------------------------------------------------------------------
# Headline: Ashley reveals how she met Musk for the 1st time, claims she was 24 & he was 51 at the time
# Sentiment: {'label': 'POSITIVE', 'score': 0.9947880506515503}
# --------------------------------------------------------------------------------
# Headline: Study finds how new technology enhances gravitational-wave detection
# Sentiment: {'label': 'POSITIVE', 'score': 0.9993897676467896}
# --------------------------------------------------------------------------------
# Headline: Stop trying to pull India down!: Pai to Rahul on drone video
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9968461394309998}
# --------------------------------------------------------------------------------
# Headline: How AI & innovation are redefining beauty and wellness landscape
# Sentiment: {'label': 'POSITIVE', 'score': 0.9996477365493774}
# --------------------------------------------------------------------------------
# Headline: US headed to dystopian future: Bikhchandani on Musk working in US govt
# Sentiment: {'label': 'POSITIVE', 'score': 0.7400269508361816}
# --------------------------------------------------------------------------------
# Headline: DeepSeek AI app suspended for local use in South Korea
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9975570440292358}
# --------------------------------------------------------------------------------
# Headline: TCS to give 4-8% average hike to employees, will link it to return-to-office mandate: Report
# Sentiment: {'label': 'NEGATIVE', 'score': 0.6848200559616089}
# --------------------------------------------------------------------------------
# Headline: Argentina Prez may face impeachment trial over promoting crypto that crashed
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9866672158241272}
# --------------------------------------------------------------------------------
# Headline: Hyderabad startup uses AI to cut construction delays & costs
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9804572463035583}
# --------------------------------------------------------------------------------
# Headline: How is nuclear facilites' tech helping maintain hygiene at Maha Kumbh?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9995427131652832}
# --------------------------------------------------------------------------------
# Headline: Ashley reveals how she met Musk for the 1st time, claims she was 24 & he was 51 at the time
# Sentiment: {'label': 'POSITIVE', 'score': 0.9947880506515503}
# --------------------------------------------------------------------------------
# Headline: Study finds how new technology enhances gravitational-wave detection
# Sentiment: {'label': 'POSITIVE', 'score': 0.9993897676467896}
# --------------------------------------------------------------------------------
# Headline: Why will captain Hardik Pandya miss MI's opening match against CSK in IPL 2025?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9973229765892029}
# --------------------------------------------------------------------------------
# Headline: Why were MI allowed to pick a replacement with higher base price?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.999016523361206}
# --------------------------------------------------------------------------------
# Headline: 3 popular superstars who married the sisters of fellow wrestlers
# Sentiment: {'label': 'POSITIVE', 'score': 0.9982956051826477}
# --------------------------------------------------------------------------------
# Headline: I respect Man United and I'm very grateful: Casemiro
# Sentiment: {'label': 'POSITIVE', 'score': 0.9998266100883484}
# --------------------------------------------------------------------------------
# Headline: Mohammad Nabi wants to play ODIs with son Hassan Eisakhil
# Sentiment: {'label': 'POSITIVE', 'score': 0.7775604128837585}
# --------------------------------------------------------------------------------
# Headline: Australia lands in Lahore ahead of Champions Trophy 2025
# Sentiment: {'label': 'POSITIVE', 'score': 0.9994256496429443}
# --------------------------------------------------------------------------------
# Headline: Mesut Ozil calls Cristiano Ronaldo 'greatest in the world'
# Sentiment: {'label': 'POSITIVE', 'score': 0.9997803568840027}
# --------------------------------------------------------------------------------
# Headline: Why Pakistan haven't picked Shadab Khan for the Champions Trophy?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9970574378967285}
# --------------------------------------------------------------------------------
# Headline: Pakistan have played good cricket..: Rohit Sharma ahead of CT 2025
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995958209037781}
# --------------------------------------------------------------------------------
# Headline: Former NZ captain set to make his debut in The Hundred
# Sentiment: {'label': 'POSITIVE', 'score': 0.9960959553718567}
# --------------------------------------------------------------------------------
# Headline: Why will captain Hardik Pandya miss MI's opening match against CSK in IPL 2025?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9973229765892029}
# --------------------------------------------------------------------------------
# Headline: Why were MI allowed to pick a replacement with higher base price?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.999016523361206}
# --------------------------------------------------------------------------------
# Headline: 3 popular superstars who married the sisters of fellow wrestlers
# Sentiment: {'label': 'POSITIVE', 'score': 0.9982956051826477}
# --------------------------------------------------------------------------------
# Headline: I respect Man United and I'm very grateful: Casemiro
# Sentiment: {'label': 'POSITIVE', 'score': 0.9998266100883484}
# --------------------------------------------------------------------------------
# Headline: Mohammad Nabi wants to play ODIs with son Hassan Eisakhil
# Sentiment: {'label': 'POSITIVE', 'score': 0.7775604128837585}
# --------------------------------------------------------------------------------
# Headline: Australia lands in Lahore ahead of Champions Trophy 2025
# Sentiment: {'label': 'POSITIVE', 'score': 0.9994256496429443}
# --------------------------------------------------------------------------------
# Headline: Mesut Ozil calls Cristiano Ronaldo 'greatest in the world'
# Sentiment: {'label': 'POSITIVE', 'score': 0.9997803568840027}
# --------------------------------------------------------------------------------
# Headline: Why Pakistan haven't picked Shadab Khan for the Champions Trophy?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9970574378967285}
# --------------------------------------------------------------------------------
# Headline: Pakistan have played good cricket..: Rohit Sharma ahead of CT 2025
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995958209037781}
# --------------------------------------------------------------------------------
# Headline: Former NZ captain set to make his debut in The Hundred
# Sentiment: {'label': 'POSITIVE', 'score': 0.9960959553718567}
# --------------------------------------------------------------------------------
# Headline: Why will captain Hardik Pandya miss MI's opening match against CSK in IPL 2025?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9973229765892029}
# --------------------------------------------------------------------------------
# Headline: Why were MI allowed to pick a replacement with higher base price?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.999016523361206}
# --------------------------------------------------------------------------------
# Headline: 3 popular superstars who married the sisters of fellow wrestlers
# Sentiment: {'label': 'POSITIVE', 'score': 0.9982956051826477}
# --------------------------------------------------------------------------------
# Headline: I respect Man United and I'm very grateful: Casemiro
# Sentiment: {'label': 'POSITIVE', 'score': 0.9998266100883484}
# --------------------------------------------------------------------------------
# Headline: Mohammad Nabi wants to play ODIs with son Hassan Eisakhil
# Sentiment: {'label': 'POSITIVE', 'score': 0.7775604128837585}
# --------------------------------------------------------------------------------
# Headline: Australia lands in Lahore ahead of Champions Trophy 2025
# Sentiment: {'label': 'POSITIVE', 'score': 0.9994256496429443}
# --------------------------------------------------------------------------------
# Headline: Mesut Ozil calls Cristiano Ronaldo 'greatest in the world'
# Sentiment: {'label': 'POSITIVE', 'score': 0.9997803568840027}
# --------------------------------------------------------------------------------
# Headline: Why Pakistan haven't picked Shadab Khan for the Champions Trophy?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9970574378967285}
# --------------------------------------------------------------------------------
# Headline: Pakistan have played good cricket..: Rohit Sharma ahead of CT 2025
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995958209037781}
# --------------------------------------------------------------------------------
# Headline: Former NZ captain set to make his debut in The Hundred
# Sentiment: {'label': 'POSITIVE', 'score': 0.9960959553718567}
# --------------------------------------------------------------------------------
# Headline: Everyone who mattered was with us at the wedding: Prateik's wife
# Sentiment: {'label': 'POSITIVE', 'score': 0.9966122508049011}
# --------------------------------------------------------------------------------
# Headline: David Tennant compares Trump to Beetlejuice character during BAFTA
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8421159386634827}
# --------------------------------------------------------------------------------
# Headline: Samay Raina's request to record statement via video call rejected by police
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9966989159584045}
# --------------------------------------------------------------------------------
# Headline: Video: Kid cries inconsolably after watching Vicky's Chhaava
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9977732300758362}
# --------------------------------------------------------------------------------
# Headline: Comedian Gaurav mocks Ranveer for quick apology in Latent row
# Sentiment: {'label': 'NEGATIVE', 'score': 0.993691086769104}
# --------------------------------------------------------------------------------
# Headline: Maha cyber cell rejects Samay's plea to record statement online
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9750036001205444}
# --------------------------------------------------------------------------------
# Headline: Priya opens up on Prateik not inviting dad Raj Babbar to wedding
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9970398545265198}
# --------------------------------------------------------------------------------
# Headline: 'All We Imagine as Light' loses BAFTA to 'Emilia Perez'
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9996708631515503}
# --------------------------------------------------------------------------------
# Headline: Rajamouli's films don't have logic, only conviction: Karan Johar
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9958147406578064}
# --------------------------------------------------------------------------------
# Headline: GTA 6 may come to PC early in 2026 as per Corsair’s CEO
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7995112538337708}
# --------------------------------------------------------------------------------
# Headline: Everyone who mattered was with us at the wedding: Prateik's wife
# Sentiment: {'label': 'POSITIVE', 'score': 0.9966122508049011}
# --------------------------------------------------------------------------------
# Headline: David Tennant compares Trump to Beetlejuice character during BAFTA
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8421159386634827}
# --------------------------------------------------------------------------------
# Headline: Samay Raina's request to record statement via video call rejected by police
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9966989159584045}
# --------------------------------------------------------------------------------
# Headline: Video: Kid cries inconsolably after watching Vicky's Chhaava
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9977732300758362}
# --------------------------------------------------------------------------------
# Headline: Comedian Gaurav mocks Ranveer for quick apology in Latent row
# Sentiment: {'label': 'NEGATIVE', 'score': 0.993691086769104}
# --------------------------------------------------------------------------------
# Headline: Maha cyber cell rejects Samay's plea to record statement online
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9750036001205444}
# --------------------------------------------------------------------------------
# Headline: Priya opens up on Prateik not inviting dad Raj Babbar to wedding
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9970398545265198}
# --------------------------------------------------------------------------------
# Headline: 'All We Imagine as Light' loses BAFTA to 'Emilia Perez'
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9996708631515503}
# --------------------------------------------------------------------------------
# Headline: Rajamouli's films don't have logic, only conviction: Karan Johar
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9958147406578064}
# --------------------------------------------------------------------------------
# Headline: GTA 6 may come to PC early in 2026 as per Corsair’s CEO
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7995112538337708}
# --------------------------------------------------------------------------------
# Headline: Everyone who mattered was with us at the wedding: Prateik's wife
# Sentiment: {'label': 'POSITIVE', 'score': 0.9966122508049011}
# --------------------------------------------------------------------------------
# Headline: David Tennant compares Trump to Beetlejuice character during BAFTA
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8421159386634827}
# --------------------------------------------------------------------------------
# Headline: Samay Raina's request to record statement via video call rejected by police
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9966989159584045}
# --------------------------------------------------------------------------------
# Headline: Video: Kid cries inconsolably after watching Vicky's Chhaava
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9977732300758362}
# --------------------------------------------------------------------------------
# Headline: Comedian Gaurav mocks Ranveer for quick apology in Latent row
# Sentiment: {'label': 'NEGATIVE', 'score': 0.993691086769104}
# --------------------------------------------------------------------------------
# Headline: Maha cyber cell rejects Samay's plea to record statement online
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9750036001205444}
# --------------------------------------------------------------------------------
# Headline: Priya opens up on Prateik not inviting dad Raj Babbar to wedding
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9970398545265198}
# --------------------------------------------------------------------------------
# Headline: 'All We Imagine as Light' loses BAFTA to 'Emilia Perez'
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9996708631515503}
# --------------------------------------------------------------------------------
# Headline: Rajamouli's films don't have logic, only conviction: Karan Johar
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9958147406578064}
# --------------------------------------------------------------------------------
# Headline: GTA 6 may come to PC early in 2026 as per Corsair’s CEO
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7995112538337708}
# --------------------------------------------------------------------------------
# Headline: PM Modi sets ₹9 lakh crore textile exports target by 2030
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8809463381767273}
# --------------------------------------------------------------------------------
# Headline: Production begins at Rajhara North Coal Block in Jharkhand
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7624050378799438}
# --------------------------------------------------------------------------------
# Headline: Gold up 11% in 2025, stays bullish on global uncertainties
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9667811393737793}
# --------------------------------------------------------------------------------
# Headline: Total Transport Systems reports nearly 2-fold profit jump
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9473368525505066}
# --------------------------------------------------------------------------------
# Headline: India-Myanmar to expand Rupee-Kyat Trade Settlement Mechanism
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8709251284599304}
# --------------------------------------------------------------------------------
# Headline: Hitesh Mehta sent to police custody in New India Cooperative Bank scam case
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9877952337265015}
# --------------------------------------------------------------------------------
# Headline: Govt wants 10 lakh registered startups in next 10 years
# Sentiment: {'label': 'NEGATIVE', 'score': 0.843892514705658}
# --------------------------------------------------------------------------------
# Headline: Unified Pension Scheme to be effective from April 1
# Sentiment: {'label': 'POSITIVE', 'score': 0.9494202136993408}
# --------------------------------------------------------------------------------
# Headline: PM Modi, Tripura CM discuss job opportunities for youth
# Sentiment: {'label': 'POSITIVE', 'score': 0.9933086633682251}
# --------------------------------------------------------------------------------
# Headline: Market Outlook: PMI, trade deficit, global data in focus
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9778534770011902}
# --------------------------------------------------------------------------------
# Headline: PM Modi sets ₹9 lakh crore textile exports target by 2030
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8809463381767273}
# --------------------------------------------------------------------------------
# Headline: Production begins at Rajhara North Coal Block in Jharkhand
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7624050378799438}
# --------------------------------------------------------------------------------
# Headline: Gold up 11% in 2025, stays bullish on global uncertainties
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9667811393737793}
# --------------------------------------------------------------------------------
# Headline: Total Transport Systems reports nearly 2-fold profit jump
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9473368525505066}
# --------------------------------------------------------------------------------
# Headline: India-Myanmar to expand Rupee-Kyat Trade Settlement Mechanism
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8709251284599304}
# --------------------------------------------------------------------------------
# Headline: Hitesh Mehta sent to police custody in New India Cooperative Bank scam case
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9877952337265015}
# --------------------------------------------------------------------------------
# Headline: Govt wants 10 lakh registered startups in next 10 years
# Sentiment: {'label': 'NEGATIVE', 'score': 0.843892514705658}
# --------------------------------------------------------------------------------
# Headline: Unified Pension Scheme to be effective from April 1
# Sentiment: {'label': 'POSITIVE', 'score': 0.9494202136993408}
# --------------------------------------------------------------------------------
# Headline: PM Modi, Tripura CM discuss job opportunities for youth
# Sentiment: {'label': 'POSITIVE', 'score': 0.9933086633682251}
# --------------------------------------------------------------------------------
# Headline: Market Outlook: PMI, trade deficit, global data in focus
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9778534770011902}
# --------------------------------------------------------------------------------
# Headline: PM Modi sets ₹9 lakh crore textile exports target by 2030
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8809463381767273}
# --------------------------------------------------------------------------------
# Headline: Production begins at Rajhara North Coal Block in Jharkhand
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7624050378799438}
# --------------------------------------------------------------------------------
# Headline: Gold up 11% in 2025, stays bullish on global uncertainties
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9667811393737793}
# --------------------------------------------------------------------------------
# Headline: Total Transport Systems reports nearly 2-fold profit jump
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9473368525505066}
# --------------------------------------------------------------------------------
# Headline: India-Myanmar to expand Rupee-Kyat Trade Settlement Mechanism
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8709251284599304}
# --------------------------------------------------------------------------------
# Headline: Hitesh Mehta sent to police custody in New India Cooperative Bank scam case
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9877952337265015}
# --------------------------------------------------------------------------------
# Headline: Govt wants 10 lakh registered startups in next 10 years
# Sentiment: {'label': 'NEGATIVE', 'score': 0.843892514705658}
# --------------------------------------------------------------------------------
# Headline: Unified Pension Scheme to be effective from April 1
# Sentiment: {'label': 'POSITIVE', 'score': 0.9494202136993408}
# --------------------------------------------------------------------------------
# Headline: PM Modi, Tripura CM discuss job opportunities for youth
# Sentiment: {'label': 'POSITIVE', 'score': 0.9933086633682251}
# --------------------------------------------------------------------------------
# Headline: Market Outlook: PMI, trade deficit, global data in focus
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9778534770011902}
# --------------------------------------------------------------------------------
